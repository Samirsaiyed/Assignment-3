# %% [markdown]
# # Assignment - 3

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Ans: Because of their reusuability which makes program shorter , easy to rean and update

# %% [markdown]
# 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?
#
# Ans: When a function is called and starts executing the function

# %% [markdown]
# 3. What statement creates a function?

# %%
def function_name(arguments):
    return arguments

# %% [markdown]
# 4. What is the difference between a function and a function call?
#
# Ans: Function means a pre-coded task which will only perform if it is called this is where function call comes into picture to achive the task.

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Ans: There is only one global scope per python program and remains there until program because varible created inside a function can only be used in that space.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?
#
# Ans: Varible in a local space is confined to that space of function can only be used in that function and therefore retains its value utill next time function is called

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Ans: It is special statement in a function used to sent result to caller who called fucntion.
#
#     yes it is posible to have return value in an expression.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Ans: It doesnt reutrn any paricular value for example if you want to  addition of number it will perform addition but not return the result without reutnn statement.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# Ans: Global varible is a varible which is not connected to any particular function i.e it is free to be called in any function and also be reused.Therefore to refer a fucntion varible to global varible we use global keyword to declare which varible are global

# %% [markdown]
# 10. What is the data type of None?

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Ans: It will import areallyourpetnamederic module.

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Ans: spam.bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Ans: I will use try and catch for preventing crash.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Ans:--> TRY CLAUSE : try clause is used when you think that program can crash so you try to run the program and it crashes         it wont disturb other part of program.
#
#     --> EXCEPT CLAUSE : except clause is used when you are trying a certain part of program but it fails so it used as a           response to exception.
